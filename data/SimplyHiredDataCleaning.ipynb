# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.5)

# %%
import pandas as pd 
import numpy as np
import os
import pyspark 
from pyspark.sql import SparkSession

# %%
df_da = pd.read_csv('simplyhired-DA-2022.csv')
df_de = pd.read_csv('simplyhired-DE-2022.csv')
df_ds = pd.read_csv('simplyhired-DS-2022.csv')

# %%
df_da.info()
df_de.info()
df_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3288 entries, 0 to 3287
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3288 non-null   int64
#  1   title        3288 non-null   object
#  2   salary       1728 non-null   object
#  3   company      3288 non-null   object
#  4   description  3288 non-null   object
#  5   location     3288 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 154.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3288 entries, 0 to 3287
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3288 non-null   int64
#  1   title        3288 non-null   object
#  2   salary       1739 non-null   object
#  3   company      3288 non-null   object
#  4   description  3288 non-null   object
#  5   location     3288 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 154.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3288 entries, 0 to 3287
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3288 non-null   int64
#  1   title        3288 non-null   object
#  2   salary       1146 non-null   object
#  3   company      3288 non-null   object
#  4   description  3288 non-null   object
#  5   location     3288 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 154.2+ KB

# %%
df_da = df_da.drop_duplicates()

df_da.head()
# Out:
#    Unnamed: 0                               title                      salary  \
# 0           0                        Data Analyst  $100,000 - $120,000 a year
# 1           1           Data Analyst/Statistician   $51,980 - $103,518 a year
# 2           2                        Data Analyst   $80,000 - $140,000 a year
# 3           3                        Data Analyst           $40 - $60 an hour
# 4           4  Program Associate I - Data Analyst    $64,467 - $84,323 a year
#
#                              company  \
# 0     Cognizant Technology Solutions
# 1  US Department of Veterans Affairs
# 2                           Best Egg
# 3                       IntegrityATL
# 4                              DPSCD
#
#                                          description                 location
# 0  Perform data analysis on large volume of healt...  Detroit, MI +1 location
# 1  Create processes for assessing quality and acc...            Ann Arbor, MI
# 2  In addition to semi-monthly salary payments, t...                   Remote
# 3  To do well in this role you need a very fine e...            United States
# 4  Demonstrated success in analyzing and interpre...              Detroit, MI

# %%
df_de = df_de.drop_duplicates()
df_de.head()
# Out:
#    Unnamed: 0                        title                      salary  \
# 0           0                Data Engineer   $72,750 - $151,798 a year
# 1           1  Data Engineer - 100% Remote                         NaN
# 2           2                Data Engineer                         NaN
# 3           3                Data Engineer           $55 - $60 an hour
# 4           4                Data Engineer  $130,000 - $145,000 a year
#
#               company                                        description  \
# 0   Detroit Red Wings  Experience building data warehouses for data s...
# 1  Paramount Pictures  The ideal candidate is an experienced data pip...
# 2        Optimal Inc.  Contribute with that overall data standard, in...
# 3  Laiba Technologies  Strong data manipulation and data analysis ski...
# 4      Human Interest  Help build a world class data environment. Wor...
#
#             location
# 0        Detroit, MI
# 1             Remote
# 2       Dearborn, MI
# 3             Remote
# 4  San Francisco, CA

# %%
df_ds = df_ds.drop_duplicates()
df_ds.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                       Data Scientist - 100% Remote
# 1           1                   Director, Data Science- SMB Labs
# 2           2                               Data Science Analyst
# 3           3  Fall 2022 Igniting Careers Diversity & Inclusi...
# 4           4  Analyst, Product Research/Analyst I, Data Scie...
#
#                        salary                       company  \
# 0                         NaN            Paramount Pictures
# 1  $214,000 - $310,000 a year                        Indeed
# 2                         NaN  Oriental Trading Company Inc
# 3                         NaN               Bank of America
# 4   $69,400 - $126,200 a year      Liberty Mutual Insurance
#
#                                          description  \
# 0  Working with data engineers to obtain useful a...
# 1  You will set science strategy for the employer...
# 2  Understanding of data measurement and data str...
# 3  Corporate Audit: This global team maintains ro...
# 4  Work with massive amounts of data (e.g., 200 m...
#
#                      location
# 0                      Remote
# 1  United States +5 locations
# 2                   Omaha, NE
# 3               Charlotte, NC
# 4                      Remote

# %%
#merging all the data into one dataframe
df_simplyhired = pd.concat([df_da, df_de, df_ds])
df_simplyhired.info()
df_simplyhired
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9864 entries, 0 to 3287
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   9864 non-null   int64
#  1   title        9864 non-null   object
#  2   salary       4613 non-null   object
#  3   company      9864 non-null   object
#  4   description  9864 non-null   object
#  5   location     9864 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 539.4+ KB
#       Unnamed: 0                                              title  \
# 0              0                                       Data Analyst
# 1              1                          Data Analyst/Statistician
# 2              2                                       Data Analyst
# 3              3                                       Data Analyst
# 4              4                 Program Associate I - Data Analyst
# ...          ...                                                ...
# 3283        3283  Postdoctoral Fellow, Data Science RWE Advanced...
# 3284        3284               Sr Associate Data Scientist (REMOTE)
# 3285        3285                       Data Analyst with Databricks
# 3286        3286                              Research Statistician
# 3287        3287                               Data Science Analyst
#
#                           salary                            company  \
# 0     $100,000 - $120,000 a year     Cognizant Technology Solutions
# 1      $51,980 - $103,518 a year  US Department of Veterans Affairs
# 2      $80,000 - $140,000 a year                           Best Egg
# 3              $40 - $60 an hour                       IntegrityATL
# 4       $64,467 - $84,323 a year                              DPSCD
# ...                          ...                                ...
# 3283                         NaN                  Johnson & Johnson
# 3284   $96,800 - $159,700 a year      The Travelers Companies, Inc.
# 3285           $60 - $65 an hour                        DataPattern
# 3286                         NaN              The Geneva Foundation
# 3287                         NaN                       MedPro Group
#
#                                             description  \
# 0     Perform data analysis on large volume of healt...
# 1     Create processes for assessing quality and acc...
# 2     In addition to semi-monthly salary payments, t...
# 3     To do well in this role you need a very fine e...
# 4     Demonstrated success in analyzing and interpre...
# ...                                                 ...
# 3283  Proven track record of consistently delivering...
# 3284  Heavy concentration in mathematics, including ...
# 3285  Development of Roadmap based on provided strat...
# 3286  Approximately 10 Hours a week (25% Effort). Po...
# 3287  Experience with exploratory data analysis. Bui...
#
#                        location
# 0       Detroit, MI +1 location
# 1                 Ann Arbor, MI
# 2                        Remote
# 3                 United States
# 4                   Detroit, MI
# ...                         ...
# 3283  United States +1 location
# 3284               Hartford, CT
# 3285                     Remote
# 3286            San Antonio, TX
# 3287             Fort Wayne, IN
#
# [9864 rows x 6 columns]

# %%
df_simplyhired= df_simplyhired.drop(columns=['Unnamed: 0'])

# %%
df_simplyhired
# Out:
#                                                   title  \
# 0                                          Data Analyst
# 1                             Data Analyst/Statistician
# 2                                          Data Analyst
# 3                                          Data Analyst
# 4                    Program Associate I - Data Analyst
# ...                                                 ...
# 3283  Postdoctoral Fellow, Data Science RWE Advanced...
# 3284               Sr Associate Data Scientist (REMOTE)
# 3285                       Data Analyst with Databricks
# 3286                              Research Statistician
# 3287                               Data Science Analyst
#
#                           salary                            company  \
# 0     $100,000 - $120,000 a year     Cognizant Technology Solutions
# 1      $51,980 - $103,518 a year  US Department of Veterans Affairs
# 2      $80,000 - $140,000 a year                           Best Egg
# 3              $40 - $60 an hour                       IntegrityATL
# 4       $64,467 - $84,323 a year                              DPSCD
# ...                          ...                                ...
# 3283                         NaN                  Johnson & Johnson
# 3284   $96,800 - $159,700 a year      The Travelers Companies, Inc.
# 3285           $60 - $65 an hour                        DataPattern
# 3286                         NaN              The Geneva Foundation
# 3287                         NaN                       MedPro Group
#
#                                             description  \
# 0     Perform data analysis on large volume of healt...
# 1     Create processes for assessing quality and acc...
# 2     In addition to semi-monthly salary payments, t...
# 3     To do well in this role you need a very fine e...
# 4     Demonstrated success in analyzing and interpre...
# ...                                                 ...
# 3283  Proven track record of consistently delivering...
# 3284  Heavy concentration in mathematics, including ...
# 3285  Development of Roadmap based on provided strat...
# 3286  Approximately 10 Hours a week (25% Effort). Po...
# 3287  Experience with exploratory data analysis. Bui...
#
#                        location
# 0       Detroit, MI +1 location
# 1                 Ann Arbor, MI
# 2                        Remote
# 3                 United States
# 4                   Detroit, MI
# ...                         ...
# 3283  United States +1 location
# 3284               Hartford, CT
# 3285                     Remote
# 3286            San Antonio, TX
# 3287             Fort Wayne, IN
#
# [9864 rows x 5 columns]

# %%
df_simplyhired.tail()
# Out:
#                                                   title  \
# 3283  Postdoctoral Fellow, Data Science RWE Advanced...
# 3284               Sr Associate Data Scientist (REMOTE)
# 3285                       Data Analyst with Databricks
# 3286                              Research Statistician
# 3287                               Data Science Analyst
#
#                          salary                        company  \
# 3283                        NaN              Johnson & Johnson
# 3284  $96,800 - $159,700 a year  The Travelers Companies, Inc.
# 3285          $60 - $65 an hour                    DataPattern
# 3286                        NaN          The Geneva Foundation
# 3287                        NaN                   MedPro Group
#
#                                             description  \
# 3283  Proven track record of consistently delivering...
# 3284  Heavy concentration in mathematics, including ...
# 3285  Development of Roadmap based on provided strat...
# 3286  Approximately 10 Hours a week (25% Effort). Po...
# 3287  Experience with exploratory data analysis. Bui...
#
#                        location
# 3283  United States +1 location
# 3284               Hartford, CT
# 3285                     Remote
# 3286            San Antonio, TX
# 3287             Fort Wayne, IN

# %%
df_simplyhired = df_simplyhired.drop_duplicates(ignore_index=True)
df_simplyhired.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        2998 non-null   object
#  1   salary       1165 non-null   object
#  2   company      2998 non-null   object
#  3   description  2998 non-null   object
#  4   location     2998 non-null   object
# dtypes: object(5)
# memory usage: 117.2+ KB

# %%
df_simplyhired['title'] = df_simplyhired['title'].str.lower()
df_simplyhired['company'] = df_simplyhired['company'].str.lower()
df_simplyhired['description'] = df_simplyhired['description'].str.lower()
df_simplyhired['location'] = df_simplyhired['location'].str.lower()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df_simplyhired
# Out:
#                                                   title  \
# 0                                          data analyst
# 1                             data analyst/statistician
# 2                                          data analyst
# 3                                          data analyst
# 4                    program associate i - data analyst
# ...                                                 ...
# 2993  postdoctoral fellow, data science rwe advanced...
# 2994               sr associate data scientist (remote)
# 2995                       data analyst with databricks
# 2996                              research statistician
# 2997                               data science analyst
#
#                           salary                            company  \
# 0     $100,000 - $120,000 a year     cognizant technology solutions
# 1      $51,980 - $103,518 a year  us department of veterans affairs
# 2      $80,000 - $140,000 a year                           best egg
# 3              $40 - $60 an hour                       integrityatl
# 4       $64,467 - $84,323 a year                              dpscd
# ...                          ...                                ...
# 2993                         NaN                  johnson & johnson
# 2994   $96,800 - $159,700 a year      the travelers companies, inc.
# 2995           $60 - $65 an hour                        datapattern
# 2996                         NaN              the geneva foundation
# 2997                         NaN                       medpro group
#
#                                             description  \
# 0     perform data analysis on large volume of healt...
# 1     create processes for assessing quality and acc...
# 2     in addition to semi-monthly salary payments, t...
# 3     to do well in this role you need a very fine e...
# 4     demonstrated success in analyzing and interpre...
# ...                                                 ...
# 2993  at johnson & johnson, we use technology and th...
# 2994  who are we? taking care of our customers, our ...
# 2995  * work with stakeholders such as business user...
# 2996  overview: the geneva foundation is a non-profi...
# 2997  meet medpro group. we’re an industry-leading b...
#
#                        location
# 0       detroit, mi +1 location
# 1                 ann arbor, mi
# 2                        remote
# 3                 united states
# 4                   detroit, mi
# ...                         ...
# 2993  united states +1 location
# 2994               hartford, ct
# 2995                     remote
# 2996            san antonio, tx
# 2997             fort wayne, in
#
# [2998 rows x 5 columns]

# %%
df_simplyhired['location'] = df_simplyhired.location.map(lambda x: x[0: x.find('+') -1] if '+' in x else x)
print(df_simplyhired)
# Out:
#                                                   title  \
# 0                                          data analyst
# 1                             data analyst/statistician
# 2                                          data analyst
# 3                                          data analyst
# 4                    program associate i - data analyst
# ...                                                 ...
# 2993  postdoctoral fellow, data science rwe advanced...
# 2994               sr associate data scientist (remote)
# 2995                       data analyst with databricks
# 2996                              research statistician
# 2997                               data science analyst
#
#                           salary                            company  \
# 0     $100,000 - $120,000 a year     cognizant technology solutions
# 1      $51,980 - $103,518 a year  us department of veterans affairs
# 2      $80,000 - $140,000 a year                           best egg
# 3              $40 - $60 an hour                       integrityatl
# 4       $64,467 - $84,323 a year                              dpscd
# ...                          ...                                ...
# 2993                         NaN                  johnson & johnson
# 2994   $96,800 - $159,700 a year      the travelers companies, inc.
# 2995           $60 - $65 an hour                        datapattern
# 2996                         NaN              the geneva foundation
# 2997                         NaN                       medpro group
#
#                                             description         location
# 0     perform data analysis on large volume of healt...      detroit, mi
# 1     create processes for assessing quality and acc...    ann arbor, mi
# 2     in addition to semi-monthly salary payments, t...           remote
# 3     to do well in this role you need a very fine e...    united states
# 4     demonstrated success in analyzing and interpre...      detroit, mi
# ...                                                 ...              ...
# 2993  at johnson & johnson, we use technology and th...    united states
# 2994  who are we? taking care of our customers, our ...     hartford, ct
# 2995  * work with stakeholders such as business user...           remote
# 2996  overview: the geneva foundation is a non-profi...  san antonio, tx
# 2997  meet medpro group. we’re an industry-leading b...   fort wayne, in
#
# [2998 rows x 5 columns]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_simplyhired['location'].value_counts()
#Remote seems to be most occuring word in the location column. Since the pandemic is slowing down, I would like to dig deeper to see if any companies are offering hybird.
# Out:
# remote               931
# new york, ny         174
# san francisco, ca    127
# united states         86
# atlanta, ga           72
#                     ...
# jackson, ms            1
# kingsburg, ca          1
# andrews afb, md        1
# detroit, il            1
# fort lewis, wa         1
# Name: location, Length: 473, dtype: int64

# %%
#Spliting "location" column into more columns, 'city', 'state', and country
df_simplyhired['location'] = df_simplyhired['location'].str.replace('d.c.', 'dc')
df_simplyhired['location'] = df_simplyhired['location'].str.strip()
df_simplyhired['location'] = df_simplyhired['location'].str.split(',')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df_simplyhired['city'] = df_simplyhired['location'].str[0]
df_simplyhired['state'] = df_simplyhired['location'].str[1]
#df_simplyhired['country'] = df_simplyhired['location'].str[2]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_simplyhired
# Out:
#                                                   title  \
# 0                                          data analyst
# 1                             data analyst/statistician
# 2                                          data analyst
# 3                                          data analyst
# 4                    program associate i - data analyst
# ...                                                 ...
# 2993  postdoctoral fellow, data science rwe advanced...
# 2994               sr associate data scientist (remote)
# 2995                       data analyst with databricks
# 2996                              research statistician
# 2997                               data science analyst
#
#                           salary                            company  \
# 0     $100,000 - $120,000 a year     cognizant technology solutions
# 1      $51,980 - $103,518 a year  us department of veterans affairs
# 2      $80,000 - $140,000 a year                           best egg
# 3              $40 - $60 an hour                       integrityatl
# 4       $64,467 - $84,323 a year                              dpscd
# ...                          ...                                ...
# 2993                         NaN                  johnson & johnson
# 2994   $96,800 - $159,700 a year      the travelers companies, inc.
# 2995           $60 - $65 an hour                        datapattern
# 2996                         NaN              the geneva foundation
# 2997                         NaN                       medpro group
#
#                                             description            location  \
# 0     perform data analysis on large volume of healt...      [detroit,  mi]
# 1     create processes for assessing quality and acc...    [ann arbor,  mi]
# 2     in addition to semi-monthly salary payments, t...            [remote]
# 3     to do well in this role you need a very fine e...     [united states]
# 4     demonstrated success in analyzing and interpre...      [detroit,  mi]
# ...                                                 ...                 ...
# 2993  at johnson & johnson, we use technology and th...     [united states]
# 2994  who are we? taking care of our customers, our ...     [hartford,  ct]
# 2995  * work with stakeholders such as business user...            [remote]
# 2996  overview: the geneva foundation is a non-profi...  [san antonio,  tx]
# 2997  meet medpro group. we’re an industry-leading b...   [fort wayne,  in]
#
#                city state
# 0           detroit    mi
# 1         ann arbor    mi
# 2            remote   NaN
# 3     united states   NaN
# 4           detroit    mi
# ...             ...   ...
# 2993  united states   NaN
# 2994       hartford    ct
# 2995         remote   NaN
# 2996    san antonio    tx
# 2997     fort wayne    in
#
# [2998 rows x 7 columns]

# %%
df_simplyhired.state.value_counts()
#count most jobs in each state.
# Out:
#  ca    353
#  ny    201
#  tx    140
#  mi    120
#  ma     91
#  va     90
#  wa     86
#  ga     83
#  mn     56
#  co     55
#  il     55
#  ne     45
#  fl     44
#  oh     43
#  nj     39
#  md     38
#  nc     37
#  dc     36
#  ct     31
#  tn     28
#  mo     27
#  ut     26
#  ia     22
#  az     18
#  or     17
#  wi     15
#  pa     13
#  ky      9
#  ks      8
#  in      8
#  de      7
#  al      7
#  nh      6
#  ok      5
#  vt      4
#  ms      3
#  ri      3
#  pr      3
#  hi      2
#  wv      2
#  sc      2
#  la      2
#  ak      2
#  ar      2
#  wy      2
#  id      2
#  nv      2
#  nm      2
# Name: state, dtype: int64

# %%
#salary column is the key column in our analysis. In order to prepare the salary data, we have to sort the values.
df_simplyhired['salary'].value_counts()
# Out:
# $60,000 - $70,000 a year     15
# $60 - $65 an hour            14
# $66,100 - $118,300 a year    14
# $55 - $60 an hour            12
# $60 - $70 an hour            11
#                              ..
# $100 - $118 an hour           1
# $80 - $95 an hour             1
# $110 - $120 an hour           1
# $84,530 - $185,792 a year     1
# $50,000 - $175,000 a year     1
# Name: salary, Length: 697, dtype: int64

# %%
df_simplyhired['salary'] = df_simplyhired['salary'].str.replace('\n', '')
df_simplyhired['salary'] = df_simplyhired['salary'].str.replace(',', '')
df_simplyhired['salary']= df_simplyhired['salary'].str.replace('$', '')
df_simplyhired['salary']= df_simplyhired['salary'].str.replace('From', '')
df_simplyhired['salary']= df_simplyhired['salary'].str.replace('Estimated:', '')
df_simplyhired['salary']= df_simplyhired['salary'].str.replace('Up to', '')
#df.tail()

#df.loc[df['Estimated_Salary'].str.contains('NaN',na=True), 'Estimated_Salary'] ='Nothing_found'
#indeed.head()
salary_data = df_simplyhired[df_simplyhired['salary'] != 'NaN']
#df =df[~df.isin(salary_data)].dropna(how='all')
#df['Estimated_Salary'].astype('float')  
df_simplyhired.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 title                  salary  \
# 0                        data analyst  100000 - 120000 a year
# 1           data analyst/statistician   51980 - 103518 a year
# 2                        data analyst   80000 - 140000 a year
# 3                        data analyst         40 - 60 an hour
# 4  program associate i - data analyst    64467 - 84323 a year
#
#                              company  \
# 0     cognizant technology solutions
# 1  us department of veterans affairs
# 2                           best egg
# 3                       integrityatl
# 4                              dpscd
#
#                                          description          location  \
# 0  perform data analysis on large volume of healt...    [detroit,  mi]
# 1  create processes for assessing quality and acc...  [ann arbor,  mi]
# 2  in addition to semi-monthly salary payments, t...          [remote]
# 3  to do well in this role you need a very fine e...   [united states]
# 4  demonstrated success in analyzing and interpre...    [detroit,  mi]
#
#             city state
# 0        detroit    mi
# 1      ann arbor    mi
# 2         remote   NaN
# 3  united states   NaN
# 4        detroit    mi

# %%
#Detect all the character imformation from each rows 
year_salaries = salary_data[salary_data["salary"].str.contains('year',na=False)]
month_salaries = salary_data[salary_data["salary"].str.contains('month',na=False)]
week_salaries = salary_data[salary_data["salary"].str.contains('week',na=False)]
day_salaries = salary_data[salary_data["salary"].str.contains('day',na=False)]
hour_salaries = salary_data[salary_data["salary"].str.contains('hour',na=False)]

#Removing all extra infromation from each rows.
year_salaries["salary"] = year_salaries["salary"].str.replace('a year', '')
month_salaries["salary"] = month_salaries["salary"].str.replace(' a month', '')
week_salaries["salary"] = week_salaries["salary"].str.replace('a week', '')
day_salaries["salary"] = day_salaries["salary"].str.replace('a day', '')
hour_salaries["salary"] = hour_salaries["salary"].str.replace('an hour', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
def split_sal(i):
    #print(i)
    #type(i)
    try:
        splt = i.split('-',1)
        #print(splt)
        first = float(splt[0])
        #print(first)
        second = float(splt[1])
        #print(second)
        return (first + second)/2
    except:
        return float(i)


    
year_salaries['salary'] = year_salaries['salary'].apply(split_sal)
month_salaries['salary'] = month_salaries['salary'].apply(split_sal)
month_salaries['salary'] = month_salaries['salary'][:] * 12
week_salaries['salary'] = week_salaries['salary'].apply(split_sal)
week_salaries['salary'] = week_salaries['salary'][:] * 52
day_salaries['salary'] = day_salaries['salary'].apply(split_sal)
day_salaries['salary'] = day_salaries['salary'][:] * 260
hour_salaries['salary'] = hour_salaries['salary'].apply(split_sal)
hour_salaries['salary'] = hour_salaries['salary'][:] * 2080

year_salaries.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 title    salary  \
# 0                        data analyst  110000.0
# 1           data analyst/statistician   77749.0
# 2                        data analyst  110000.0
# 4  program associate i - data analyst   74395.0
# 5                 remote data analyst   62000.0
#
#                              company  \
# 0     cognizant technology solutions
# 1  us department of veterans affairs
# 2                           best egg
# 4                              dpscd
# 5              adt security services
#
#                                          description          location  \
# 0  perform data analysis on large volume of healt...    [detroit,  mi]
# 1  create processes for assessing quality and acc...  [ann arbor,  mi]
# 2  in addition to semi-monthly salary payments, t...          [remote]
# 4  demonstrated success in analyzing and interpre...    [detroit,  mi]
# 5  familiarity with mastermind business/monitorin...          [remote]
#
#         city state
# 0    detroit    mi
# 1  ann arbor    mi
# 2     remote   NaN
# 4    detroit    mi
# 5     remote   NaN

# %%
#Getting the average salary
combined_salaries = pd.concat([year_salaries,month_salaries, week_salaries, day_salaries, hour_salaries], axis=0)

average_salary=0
j=1
for ind in combined_salaries.index:
    df_simplyhired['salary'][ind]=combined_salaries['salary'][ind]
    j=j+1
    average_salary=average_salary+combined_salaries['salary'][ind]
average_salary=average_salary/j

# Substitute the empty salary cells with the average salary

avg_sal=df_simplyhired[~df_simplyhired.isin(combined_salaries)].dropna(how='all')
for ind in avg_sal.index:
    df_simplyhired['salary'][ind]=average_salary
df_simplyhired.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                                 title    salary  \
# 0                        data analyst  110000.0
# 1           data analyst/statistician   77749.0
# 2                        data analyst  110000.0
# 3                        data analyst  104000.0
# 4  program associate i - data analyst   74395.0
#
#                              company  \
# 0     cognizant technology solutions
# 1  us department of veterans affairs
# 2                           best egg
# 3                       integrityatl
# 4                              dpscd
#
#                                          description          location  \
# 0  perform data analysis on large volume of healt...    [detroit,  mi]
# 1  create processes for assessing quality and acc...  [ann arbor,  mi]
# 2  in addition to semi-monthly salary payments, t...          [remote]
# 3  to do well in this role you need a very fine e...   [united states]
# 4  demonstrated success in analyzing and interpre...    [detroit,  mi]
#
#             city state
# 0        detroit    mi
# 1      ann arbor    mi
# 2         remote   NaN
# 3  united states   NaN
# 4        detroit    mi

# %%
df_simplyhired.head(50)
# Out:
#                                                 title         salary  \
# 0                                        data analyst       110000.0
# 1                           data analyst/statistician        77749.0
# 2                                        data analyst       110000.0
# 3                                        data analyst       104000.0
# 4                  program associate i - data analyst        74395.0
# 5                                 remote data analyst        62000.0
# 6                  program associate i - data analyst        74395.0
# 7                            entry level data analyst  115871.092967
# 8                                     program analyst       106909.0
# 9                 professional administrative analyst        63453.0
# 10                             billing data analyst i        71000.0
# 11                           entry level data analyst        59280.0
# 12                                  cdao data analyst       105832.0
# 13                     business data analyst (remote)        95000.0
# 14  part-time data entry analyst - solvas financia...  115871.092967
# 15                           entry level data analyst       104000.0
# 16                                junior data analyst        42500.0
# 17               data reporting analyst - entry level        65000.0
# 18                              location data analyst        67500.0
# 19                                       data analyst        63000.0
# 20                  senior data analyst- remote (est)       143000.0
# 21                        data analyst - mobile games       110000.0
# 22                               finance data analyst  115871.092967
# 23                               data support analyst  115871.092967
# 24                                   business analyst        87500.0
# 25                     remote-data technician analyst        51206.0
# 26                                       data analyst  115871.092967
# 27                         data analyst - stratascale  115871.092967
# 28             remote provider data service analyst 1  115871.092967
# 29                        analyst, reporting and data       118800.0
# 30                                       data analyst        79900.0
# 31                               data research master  115871.092967
# 32                              data analyst (remote)  115871.092967
# 33  it data analyst - fintech + growing + profitab...        85000.0
# 34                                       data analyst        67600.0
# 35           junior data analyst - dal22-033349999999  115871.092967
# 36                 entry level business /data analyst        67600.0
# 37  reporting analyst / data analyst (healthcare e...        60975.2
# 38              senior data analyst, games & live ops  115871.092967
# 39                            data operations analyst  115871.092967
# 40                                       data analyst  115871.092967
# 41             data analyst for fresher (opt student)  115871.092967
# 42                    data analyst (consumer finance)  115871.092967
# 43                             data analyst ii-remote  115871.092967
# 44                             logistics data analyst  115871.092967
# 45                               digital data analyst       117500.0
# 46                                   crm data analyst        82500.0
# 47                                       data analyst        75000.0
# 48                                            analyst        43000.0
# 49  data reporting analyst (healthcare experience ...        61027.2
#
#                                       company  \
# 0              cognizant technology solutions
# 1           us department of veterans affairs
# 2                                    best egg
# 3                                integrityatl
# 4                                       dpscd
# 5                       adt security services
# 6   detroit public schools community district
# 7                                  antra, inc
# 8                    u.s. department of state
# 9                 great lakes water authority
# 10                                     indeed
# 11                                    tresume
# 12                             general motors
# 13                       digital strategy llc
# 14                                   deloitte
# 15                                emonics llc
# 16                                    teamson
# 17                            pcs global tech
# 18                                     indeed
# 19                        lakeshore legal aid
# 20                           suncoast drivers
# 21                         carbon counts tech
# 22                      computer solution llc
# 23                 willson international ltd.
# 24                           k-tek resourcing
# 25                     self insured reporting
# 26                               optimal inc.
# 27                    shi international corp.
# 28                               coventry wcs
# 29                                      chime
# 30                                       dish
# 31                                        ucd
# 32                           home depot / thd
# 33                          relentless talent
# 34                         vortex trading llc
# 35               evergreen technologies, llc.
# 36                                    tresume
# 37                           mosquito hunters
# 38                         playstation global
# 39         telus agriculture & consumer goods
# 40                       winwire technologies
# 41                        cloudbig technology
# 42                            smiledirectclub
# 43                       michigan health plan
# 44                          central transport
# 45                          canyon associates
# 46                                  smartwyre
# 47                                   genspark
# 48                        the freedonia group
# 49                           mosquito hunters
#
#                                           description               location  \
# 0   perform data analysis on large volume of healt...         [detroit,  mi]
# 1   create processes for assessing quality and acc...       [ann arbor,  mi]
# 2   in addition to semi-monthly salary payments, t...               [remote]
# 3   to do well in this role you need a very fine e...        [united states]
# 4   demonstrated success in analyzing and interpre...         [detroit,  mi]
# 5   familiarity with mastermind business/monitorin...               [remote]
# 6   demonstrated success in analyzing and interpre...         [detroit,  mi]
# 7   secure access to data sources determine data a...               [remote]
# 8   experience assisting in the integration of qua...      [washington,  dc]
# 9   business technology, data management systems, ...         [detroit,  mi]
# 10  in this role as an operations analyst, you’ll ...        [united states]
# 11  perform data cleanups and document processes. ...       [chantilly,  va]
# 12  additionally, you will be responsible for work...               [remote]
# 13  supports data efforts in system modernization ...               [remote]
# 14  this is a part-time syndicated loan data entry...         [detroit,  mi]
# 15  collaborate with healthcare analytics business...               [remote]
# 16  at least two years of experience as an analyst...               [remote]
# 17  regularly examine data reports to locate and r...         [seattle,  wa]
# 18  3-5 years experience in a data analyst or gis ...        [united states]
# 19  assess and ensure quality of data. create repo...         [detroit,  mi]
# 20  analyze data for data gaps and make recommenda...             [maryland]
# 21  data analysis skills: 5 years (required). you ...               [remote]
# 22  experience in data analysis and working with l...               [remote]
# 23  college degree or business experience equivale...       [southgate,  mi]
# 24  > business analysis services, work closely wit...               [remote]
# 25  understand the data integration process from s...               [remote]
# 26  work with on-prem data sources (hadoop, sql se...        [dearborn,  mi]
# 27  1-3 years’ experience in data analysis with po...         [detroit,  mi]
# 28  provides support for baseline provider data tr...        [united states]
# 29  synthesize data and build consensus by clearly...   [san francisco,  ca]
# 30  experience with big data platforms (e.g. aws, ...  [christiansburg,  va]
# 31  we need a researcher to help gather, organize,...               [remote]
# 32  1-2 years of data analysis experience. address...         [atlanta,  ga]
# 33  assume data support responsibilities from curr...         [detroit,  mi]
# 34  proven working experience as a data analyst or...        [cromwell,  ct]
# 35  experience with data wrangling, data cleaning ...         [detroit,  mi]
# 36  knowledge of data visualization software like ...       [baltimore,  md]
# 37  advanced excel (pivot tables, etc...), powerpo...               [remote]
# 38  demonstrated analytical skills working with la...       [san mateo,  ca]
# 39  performs data reconciliations, validation and ...               [remote]
# 40  providing resource to add/delete/amend data wi...               [remote]
# 41  responsible for ensuring data accuracy and dat...               [remote]
# 42  use data to optimize payment authorization rat...               [remote]
# 43  o internal data cleansing and data reconciliat...         [detroit,  mi]
# 44  this is a full time opportunity, working *mond...          [warren,  mi]
# 45  bachelor's degree remote role experience confi...               [remote]
# 46  the crm data analyst will perform various func...               [remote]
# 47  location: *remote *for now ( relocation after ...               [remote]
# 48  analyze data and place into standard formats t...               [remote]
# 49  data/reporting analyst will be responsible for...               [remote]
#
#               city state
# 0          detroit    mi
# 1        ann arbor    mi
# 2           remote   NaN
# 3    united states   NaN
# 4          detroit    mi
# 5           remote   NaN
# 6          detroit    mi
# 7           remote   NaN
# 8       washington    dc
# 9          detroit    mi
# 10   united states   NaN
# 11       chantilly    va
# 12          remote   NaN
# 13          remote   NaN
# 14         detroit    mi
# 15          remote   NaN
# 16          remote   NaN
# 17         seattle    wa
# 18   united states   NaN
# 19         detroit    mi
# 20        maryland   NaN
# 21          remote   NaN
# 22          remote   NaN
# 23       southgate    mi
# 24          remote   NaN
# 25          remote   NaN
# 26        dearborn    mi
# 27         detroit    mi
# 28   united states   NaN
# 29   san francisco    ca
# 30  christiansburg    va
# 31          remote   NaN
# 32         atlanta    ga
# 33         detroit    mi
# 34        cromwell    ct
# 35         detroit    mi
# 36       baltimore    md
# 37          remote   NaN
# 38       san mateo    ca
# 39          remote   NaN
# 40          remote   NaN
# 41          remote   NaN
# 42          remote   NaN
# 43         detroit    mi
# 44          warren    mi
# 45          remote   NaN
# 46          remote   NaN
# 47          remote   NaN
# 48          remote   NaN
# 49          remote   NaN

# %%
df_simplyhired.to_csv('SimplyHiredCleanData.csv', index=False)
