# %%
import numpy as np
import pandas as pd
import os
import re

# %% [markdown]
# ## Importing data

# %%
os.chdir(r'C:\Users\chitr\gc-march-2022\data')

# %%
df_da = pd.read_csv('dice_DataAnalyst_2022.csv')
df_da.head(5)
# Out:
#    Unnamed: 0           title                company  \
# 0           0   Data Analyst        3K Technologies
# 1           1   Data Analyst       IDC Technologies
# 2           2   Data Analyst             AIMIC Inc.
# 3           3   Data Analyst        Vaco Technology
# 4           4   Data Analyst    Nivid InfoTech Inc.
#
#                                          description  \
# 0  Data Analyst Eden Prairie, MN (Remote) 1 Year ...
# 1  Data Analyst  100% remote Contract   Job Descr...
# 2  Data Analyst Reston, VA (Remote to start but M...
# 3  Job Title: Data Analyst  Location: New York/ R...
# 4  Data Analyst  Atlanta, GA ( Remote to start ) ...
#
#                        location
# 0                       Remote
# 1                       Remote
# 2                       Remote
# 3            New York, NY, USA
# 4   Remote or Atlanta, GA, USA

# %%
df_da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   921 non-null    int64
#  1   title        921 non-null    object
#  2   company      921 non-null    object
#  3   description  921 non-null    object
#  4   location     921 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 36.1+ KB

# %%
df_de = pd.read_csv('dice_DataEngineer_2022.csv')

# %%
df_de.head(5)
# Out:
#    Unnamed: 0                          title                         company  \
# 0           0   Data Engineer 3 (Technical)        Northwest Permanente, PC
# 1           1    Data & Automation Engineer    ClearBridge Investments, LLC
# 2           2                 Data Engineer       The Ascent Services Group
# 3           3                 Data Engineer           Softpath System, LLC.
# 4           4                 Data Engineer                 Mastech Digital
#
#                                          description  \
# 0  The Data Engineer 3 position provides the oppo...
# 1  ClearBridge Investments is a leading global eq...
# 2  Title: Data Engineer  Location: Denver, CO  Ty...
# 3  Job Details: Job Title  : Data Engineer Work L...
# 4  Mastech Digital provides digital and mainstrea...
#
#                           location
# 0               Portland, OR, USA
# 1               New York, NY, USA
# 2               Glendale, CO, USA
# 3                Shawnee, KS, USA
# ...

# %%
df_de.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1992 entries, 0 to 1991
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1992 non-null   int64
#  1   title        1992 non-null   object
#  2   company      1992 non-null   object
#  3   description  1992 non-null   object
#  4   location     1992 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 77.9+ KB

# %%
df_ds = pd.read_csv('dice_Datascientist_2022.csv')

# %%
df_ds.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                            Data Science Architect
# 1           1                              Data Science Trainee
# 2           2                                      Data Science
# 3           3   Urgent Opening | Product Manager Data Science...
# 4           4   Project Manager (With Data Science Experience )
#
#                    company                                        description  \
# 0   Randstad Technologies   job summary:  The Data Science Architect works...
# 1      HStechnologies LLC   HS Technologies, is an Equal Opportunity Emplo...
# 2      Ventures Unlimited   Position:- Data Science ,   Location:- Austin,...
# 3   SunRay Enterprise Inc   Hi All,Hope you are doing well!  Please see th...
# 4        WB Solutions LLC   Greetings from WB Solutions!   We have the Urg...
#
#                    location
# 0   North Chicago, IL, USA
# 1                   Remote
# ...

# %%
df_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1990 entries, 0 to 1989
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1990 non-null   int64
#  1   title        1990 non-null   object
#  2   company      1990 non-null   object
#  3   description  1990 non-null   object
#  4   location     1990 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 77.9+ KB

# %% [markdown]
# None of the columns from all three files contains null value.

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ###  Checking and dropping any duplicate rows

# %%
df_da = df_da.drop_duplicates()
df_da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 921 entries, 0 to 920
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   921 non-null    int64
#  1   title        921 non-null    object
#  2   company      921 non-null    object
#  3   description  921 non-null    object
#  4   location     921 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 43.2+ KB

# %%
df_de = df_de.drop_duplicates()
df_de.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 1991
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1992 non-null   int64
#  1   title        1992 non-null   object
#  2   company      1992 non-null   object
#  3   description  1992 non-null   object
#  4   location     1992 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 93.4+ KB

# %%
df_ds= df_ds.drop(columns=['Unnamed: 0'])
df_ds = df_ds.drop_duplicates()
df_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1561 entries, 0 to 1987
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1561 non-null   object
#  1   company      1561 non-null   object
#  2   description  1561 non-null   object
#  3   location     1561 non-null   object
# dtypes: object(4)
# memory usage: 61.0+ KB

# %% [markdown]
# #### Merging all the data into one dataframe

# %%
df_dice = pd.concat([df_da,df_de,df_ds])
df_dice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4474 entries, 0 to 1987
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2913 non-null   float64
#  1   title        4474 non-null   object
#  2   company      4474 non-null   object
#  3   description  4474 non-null   object
#  4   location     4474 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 209.7+ KB

# %%
df_dice.head()
# Out:
#    Unnamed: 0           title                company  \
# 0         0.0   Data Analyst        3K Technologies
# 1         1.0   Data Analyst       IDC Technologies
# 2         2.0   Data Analyst             AIMIC Inc.
# 3         3.0   Data Analyst        Vaco Technology
# 4         4.0   Data Analyst    Nivid InfoTech Inc.
#
#                                          description  \
# 0  Data Analyst Eden Prairie, MN (Remote) 1 Year ...
# 1  Data Analyst  100% remote Contract   Job Descr...
# 2  Data Analyst Reston, VA (Remote to start but M...
# 3  Job Title: Data Analyst  Location: New York/ R...
# 4  Data Analyst  Atlanta, GA ( Remote to start ) ...
#
#                        location
# 0                       Remote
# 1                       Remote
# 2                       Remote
# 3            New York, NY, USA
# 4   Remote or Atlanta, GA, USA

# %%
df_dice.tail()
# Out:
#       Unnamed: 0                    title   company  \
# 1982         NaN   Lead Flight Engineers    BOEING
# 1983         NaN   Lead Flight Engineers    BOEING
# 1984         NaN   Lead Flight Engineers    BOEING
# 1985         NaN   Lead Flight Engineers    BOEING
# 1987         NaN   Lead Flight Engineers    BOEING
#
#                                             description  \
# 1982  Job Description  At Boeing, we innovate and co...
# 1983  Job Description  At Boeing, we innovate and co...
# 1984  Job Description  At Boeing, we innovate and co...
# 1985  Job Description  At Boeing, we innovate and co...
# 1987  Job Description  At Boeing, we innovate and co...
#
#                     location
# 1982    Louisville, CO, USA
# 1983        Arvada, CO, USA
# 1984        Parker, CO, USA
# 1985      Idledale, CO, USA
# 1987   Westminster, CA, USA

# %%
df_dice= df_dice.drop(columns=['Unnamed: 0'])
df_dice = df_dice.drop_duplicates(ignore_index=True)
df_dice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3917 entries, 0 to 3916
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        3917 non-null   object
#  1   company      3917 non-null   object
#  2   description  3917 non-null   object
#  3   location     3917 non-null   object
# dtypes: object(4)
# memory usage: 122.5+ KB

# %%
df_dice.tail()
# Out:
#                         title   company  \
# 3912   Lead Flight Engineers    BOEING
# 3913   Lead Flight Engineers    BOEING
# 3914   Lead Flight Engineers    BOEING
# 3915   Lead Flight Engineers    BOEING
# 3916   Lead Flight Engineers    BOEING
#
#                                             description  \
# 3912  Job Description  At Boeing, we innovate and co...
# 3913  Job Description  At Boeing, we innovate and co...
# 3914  Job Description  At Boeing, we innovate and co...
# 3915  Job Description  At Boeing, we innovate and co...
# 3916  Job Description  At Boeing, we innovate and co...
#
#                     location
# 3912    Louisville, CO, USA
# 3913        Arvada, CO, USA
# 3914        Parker, CO, USA
# 3915      Idledale, CO, USA
# 3916   Westminster, CA, USA

# %% [markdown]
# ##### This dataset does have enough amount of rows to start with initial analysis. But I do see that some job roles and descriptions are same but just change in location created more rows in the dataset. That needs to be investigated more.

# %%
df_dice['title'] = df_dice['title'].str.lower()
df_dice['company'] = df_dice['company'].str.lower()
df_dice['description'] = df_dice['description'].str.lower()
df_dice['location'] = df_dice['location'].str.lower()

# %%
df_dice
# Out:
#                         title                company  \
# 0               data analyst        3k technologies
# 1               data analyst       idc technologies
# 2               data analyst             aimic inc.
# 3               data analyst        vaco technology
# 4               data analyst    nivid infotech inc.
# ...                       ...                    ...
# 3912   lead flight engineers                 boeing
# 3913   lead flight engineers                 boeing
# 3914   lead flight engineers                 boeing
# 3915   lead flight engineers                 boeing
# 3916   lead flight engineers                 boeing
#
#                                             description  \
# 0     data analyst eden prairie, mn (remote) 1 year ...
# 1     data analyst  100% remote contract   job descr...
# 2     data analyst reston, va (remote to start but m...
# 3     job title: data analyst  location: new york/ r...
# ...

# %%
df_dice['location'].value_counts()
# Out:
#  remote                        638
#  new york, ny, usa             154
#  los angeles, ca, usa          120
#  chicago, il, usa               66
#  atlanta, ga, usa               66
#                               ...
#  urbandale, ia, usa              1
#  remote or vienna, va, usa       1
#  east moline, il, usa            1
#  gurugram, hr, india             1
#  idledale, co, usa               1
# Name: location, Length: 888, dtype: int64

# %% [markdown]
# ##### Remote seems to be the most occurring keyword. Also, there are some companies giving options for remote as well as in-person. So to analyze how many in total remote jobs let's create one more column is_remote.

# %%
import numpy as np

df_dice['is_remote'] = np.where(df_dice['location'].str.contains('remote'),1,0)
df_dice
# Out:
#                         title                company  \
# 0               data analyst        3k technologies
# 1               data analyst       idc technologies
# 2               data analyst             aimic inc.
# 3               data analyst        vaco technology
# 4               data analyst    nivid infotech inc.
# ...                       ...                    ...
# 3912   lead flight engineers                 boeing
# 3913   lead flight engineers                 boeing
# 3914   lead flight engineers                 boeing
# 3915   lead flight engineers                 boeing
# 3916   lead flight engineers                 boeing
#
#                                             description  \
# 0     data analyst eden prairie, mn (remote) 1 year ...
# 1     data analyst  100% remote contract   job descr...
# 2     data analyst reston, va (remote to start but m...
# 3     job title: data analyst  location: new york/ r...
# ...

# %% [markdown]
# ##### Lets split 'location' column into create more columns, 'city', 'state' and 'country', to further analyze jobs by state or city.

# %%
df_dice['location'] = df_dice['location'].str.replace('d.c.', 'dc')
df_dice['location'] = df_dice['location'].str.strip()
df_dice['location'] = df_dice['location'].str.split(',')
# Out:
# C:\Users\chitr\AppData\Local\Temp\ipykernel_7904\2435904984.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_dice['location'] = df_dice['location'].str.replace('d.c.', 'dc')

# %%
df_dice['city'] = df_dice['location'].str[0]
df_dice['state'] = df_dice['location'].str[1]
df_dice['country'] = df_dice['location'].str[2]

# %%
df_dice
# Out:
#                         title                company  \
# 0               data analyst        3k technologies
# 1               data analyst       idc technologies
# 2               data analyst             aimic inc.
# 3               data analyst        vaco technology
# 4               data analyst    nivid infotech inc.
# ...                       ...                    ...
# 3912   lead flight engineers                 boeing
# 3913   lead flight engineers                 boeing
# 3914   lead flight engineers                 boeing
# 3915   lead flight engineers                 boeing
# 3916   lead flight engineers                 boeing
#
#                                             description  \
# 0     data analyst eden prairie, mn (remote) 1 year ...
# 1     data analyst  100% remote contract   job descr...
# 2     data analyst reston, va (remote to start but m...
# 3     job title: data analyst  location: new york/ r...
# ...

# %%
df_dice['city'] = df_dice['city'].str.replace('remote', '')
df_dice['city'] = df_dice['city'].str.replace('remote or  ', '')
df_dice['city'] = df_dice['city'].str.replace(' or ', '')

# %%
df_dice
# Out:
#                         title                company  \
# 0               data analyst        3k technologies
# 1               data analyst       idc technologies
# 2               data analyst             aimic inc.
# 3               data analyst        vaco technology
# 4               data analyst    nivid infotech inc.
# ...                       ...                    ...
# 3912   lead flight engineers                 boeing
# 3913   lead flight engineers                 boeing
# 3914   lead flight engineers                 boeing
# 3915   lead flight engineers                 boeing
# 3916   lead flight engineers                 boeing
#
#                                             description  \
# 0     data analyst eden prairie, mn (remote) 1 year ...
# 1     data analyst  100% remote contract   job descr...
# 2     data analyst reston, va (remote to start but m...
# 3     job title: data analyst  location: new york/ r...
# ...

# %%
df_dice.country.value_counts()
#df_dice[df_dice['state'].str.contains('dc', na=False)]
# Out:
#  usa       3158
#  dc          45
#  canada       9
#  mexico       1
#  india        1
# Name: country, dtype: int64

# %%
df_dice.drop(index = [878,1175,2268,2824,2999,511,628,338,947,1743,3041,2076], axis=0,inplace = True)

# %%
df_dice.country.value_counts()
# Out:
#  usa    3158
#  dc       45
# Name: country, dtype: int64

# %%
df_dice['country'] = df_dice['country'].str.replace('DC', 'USA')
df_dice.country.value_counts()
# Out:
#  usa    3158
#  dc       45
# Name: country, dtype: int64

# %%
df_dice['job_type'] = np.where(df_dice['title'].str.contains('analy'),'Data Analyst','0')
df_dice['job_type'] = np.where(df_dice['title'].str.contains('engineer'),'Data Engineer',df_dice['job_type'])
df_dice['job_type'] = np.where(df_dice['title'].str.contains('scien'),'Data Scientist',df_dice['job_type'])
df_dice['job_type'] = np.where(df_dice['job_type'] == '0','Other',df_dice['job_type'])
df_dice
# Out:
#                         title                company  \
# 0               data analyst        3k technologies
# 1               data analyst       idc technologies
# 2               data analyst             aimic inc.
# 3               data analyst        vaco technology
# 4               data analyst    nivid infotech inc.
# ...                       ...                    ...
# 3912   lead flight engineers                 boeing
# 3913   lead flight engineers                 boeing
# 3914   lead flight engineers                 boeing
# 3915   lead flight engineers                 boeing
# 3916   lead flight engineers                 boeing
#
#                                             description  \
# 0     data analyst eden prairie, mn (remote) 1 year ...
# 1     data analyst  100% remote contract   job descr...
# 2     data analyst reston, va (remote to start but m...
# 3     job title: data analyst  location: new york/ r...
# ...

# %%
employmenttypes = [ 'full time','part time', 'contract', 'long term', '6 months', '12 months']

df_dice['employment_type'] = np.nan

for ind in df_dice.index:
    desc=df_dice['description'][ind]
 
    desc = re.sub("[^a-zA-Z0-12]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(desc))
    lst = ''
    for emptype in employmenttypes:
        if  re.search(emptype,desc):
            lst=lst+emptype+','
    lst = lst[:-1]
   
    if ind < len(df_dice):
        df_dice['employment_type'].iloc[ind]=lst

df_dice.head(10)
# Out:
# C:\Users\chitr\AppData\Local\Temp\ipykernel_7904\1788771951.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dice['employment_type'].iloc[ind]=lst
#             title                  company  \
# 0   data analyst          3k technologies
# 1   data analyst         idc technologies
# 2   data analyst               aimic inc.
# 3   data analyst          vaco technology
# 4   data analyst      nivid infotech inc.
# 5   data analyst                bcforward
# 6   data analyst                   kabtec
# 7   data analyst    randstad technologies
# 8   data analyst          sira consulting
# 9   data analyst            compugain llc
#
#                                          description  \
# 0  data analyst eden prairie, mn (remote) 1 year ...
# ...

# %%
df_dice.employment_type.value_counts()
# Out:
#                                 3084
# contract                         308
# full time                        244
# long term                         84
# contract,long term                82
# 12 months                         44
# contract,12 months                24
# full time,contract                12
# contract,long term,12 months       4
# full time,contract,long term       3
# full time,part time                2
# full time,long term                2
# Name: employment_type, dtype: int64

# %%
experience_levels = ['associate','senior','intern','principal',
                  'director','leader','manager','specialist','entry level','machine learning'
                    ,'junior','jr','sr']

df_dice['experience_level'] = np.nan
for index,level in enumerate(experience_levels):
    df_dice['experience_level'] = np.where(df_dice['description'].str.contains(level),level,df_dice['experience_level'])

# %%
df_dice.experience_level.value_counts()
# Out:
# nan                 2526
# senior               334
# sr                   261
# leader               234
# machine learning     163
# manager              124
# intern                82
# director              51
# associate             45
# specialist            28
# principal             24
# junior                20
# jr                     9
# entry level            4
# Name: experience_level, dtype: int64

# %%
df_dice['experience_level'] =df_dice['experience_level'].str.replace('sr','senior')
df_dice['experience_level'] =df_dice['experience_level'].str.replace('jr','junior')

# %%
df_dice.experience_level.value_counts()
# Out:
# nan                 2526
# senior               595
# leader               234
# machine learning     163
# manager              124
# intern                82
# director              51
# associate             45
# junior                29
# specialist            28
# principal             24
# entry level            4
# Name: experience_level, dtype: int64

# %%
skills=['python','java','sql','spark','hadoop','bigdata','machine learning','hive','pig','git','nosql','aws','azure', 'power bi', 'tableau','etl','agile','relational databases','postgres','matlab','graphql','data analysis','excel','data modeling','shell scripting','gcp','cloud computing','deep learning','nlp','flask','eda']

df_dice['skills'] = np.nan

for ind in df_dice.index:
    desc=df_dice['description'][ind]
 
    desc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(desc))
    lst = ''
    for skill in skills:
        if  re.search(skill,desc):
            lst=lst+skill+','
    lst = lst[:-1]
   
    if ind < len(df_dice):
        df_dice['skills'].iloc[ind]=lst

df_dice.head(10)
# Out:
# C:\Users\chitr\AppData\Local\Temp\ipykernel_7904\2869466735.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dice['skills'].iloc[ind]=lst
#             title                  company  \
# 0   data analyst          3k technologies
# 1   data analyst         idc technologies
# 2   data analyst               aimic inc.
# 3   data analyst          vaco technology
# 4   data analyst      nivid infotech inc.
# 5   data analyst                bcforward
# 6   data analyst                   kabtec
# 7   data analyst    randstad technologies
# 8   data analyst          sira consulting
# 9   data analyst            compugain llc
#
#                                          description  \
# 0  data analyst eden prairie, mn (remote) 1 year ...
# 1  data analyst  100% remote contract   job descr...
# ...

# %%
df_dice['state'] = df_dice['state'].str.strip()
df_dice['city'] = df_dice['city'].str.strip()

# %%
df_dice.to_csv(r'C:\Users\chitr\gc-march-2022\DiceCleanedData.csv', index=False)
